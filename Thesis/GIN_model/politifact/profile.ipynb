# %%
# !pip3 install torch==1.8.1+cpu torchvision==0.9.1+cpu torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Collecting torch==1.8.1+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torch-1.8.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (169.1 MB)
#      |████████████████████████████████| 169.1 MB 59 kB/s
# Collecting torchvision==0.9.1+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torchvision-0.9.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (13.3 MB)
#      |████████████████████████████████| 13.3 MB 117 kB/s
# Collecting torchaudio===0.8.1
#   Downloading torchaudio-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 4.1 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cpu) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cpu) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.1+cpu) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu102
#     Uninstalling torchvision-0.10.0+cu102:
#       Successfully uninstalled torchvision-0.10.0+cu102
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.8.1+cpu which is incompatible.
# Successfully installed torch-1.8.1+cpu torchaudio-0.8.1 torchvision-0.9.1+cpu

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# !pip install torch-geometric
# !pip install --upgrade git+https://github.com/rusty1s/pytorch_geometric.git
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# Collecting torch-scatter
#   Downloading https://pytorch-geometric.com/whl/torch-1.8.0%2Bcu111/torch_scatter-2.0.8-cp37-cp37m-linux_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.0 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.8
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# Collecting torch-sparse
#   Downloading https://pytorch-geometric.com/whl/torch-1.8.0%2Bcu111/torch_sparse-0.6.11-cp37-cp37m-linux_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 312 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.19.5)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.11
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# Collecting torch-cluster
#   Downloading https://pytorch-geometric.com/whl/torch-1.8.0%2Bcu111/torch_cluster-1.5.9-cp37-cp37m-linux_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.4 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.5.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu111.html
# Collecting torch-spline-conv
#   Downloading https://pytorch-geometric.com/whl/torch-1.8.0%2Bcu111/torch_spline_conv-1.2.1-cp37-cp37m-linux_x86_64.whl (422 kB)
#      |████████████████████████████████| 422 kB 4.2 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Collecting torch-geometric
#   Downloading torch_geometric-1.7.2.tar.gz (222 kB)
#      |████████████████████████████████| 222 kB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.5.1)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.15)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.22.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.1.5)
# Collecting rdflib
#   Downloading rdflib-6.0.0-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 44.5 MB/s
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx->torch-geometric) (4.4.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric) (57.2.0)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.8 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.0.1)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.7.2-py3-none-any.whl size=388142 sha256=5b7b764d01a65dd7e1db9f30ba3e5df77f367874e0db50ecf58c50580e668820
#   Stored in directory: /root/.cache/pip/wheels/55/93/b6/2eeb0465afe89aee74d7a07a606e9770466d7565abd45a99d5
# Successfully built torch-geometric
# Installing collected packages: isodate, rdflib, torch-geometric
# Successfully installed isodate-0.6.0 rdflib-6.0.0 torch-geometric-1.7.2
# Collecting git+https://github.com/rusty1s/pytorch_geometric.git
#   Cloning https://github.com/rusty1s/pytorch_geometric.git to /tmp/pip-req-build-251qpisb
#   Running command git clone -q https://github.com/rusty1s/pytorch_geometric.git /tmp/pip-req-build-251qpisb
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.5.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (0.22.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.1.5)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (6.0.0)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric==1.7.2) (2.0.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx->torch-geometric==1.7.2) (4.4.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.7.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.7.2) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.7.2) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.7.2) (57.2.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.7.2) (0.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.7.2) (1.0.1)

# %%
import argparse
import os.path as osp

import torch
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.datasets import UPFD
from torch_geometric.data import DataLoader
from torch_geometric.transforms import ToUndirected
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, global_max_pool, global_mean_pool
from torch_geometric.nn import GINConv, global_add_pool,GINEConv
from torch.nn import Sequential, Linear, BatchNorm1d, ReLU

# %%
path = osp.join(osp.dirname(osp.realpath("/content/tutorial1")), '..', 'data', 'UPFD')
train_dataset = UPFD(path, 'politifact', 'profile', 'train', ToUndirected())
val_dataset = UPFD(path, 'politifact', 'profile', 'val', ToUndirected())
test_dataset = UPFD(path, 'politifact', 'profile', 'test', ToUndirected())

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# feature: profile --------ACC=77
#
# feature: spacy----------ACC=77
#
# feature: bert----------ACC=80

# %%
print(val_dataset)
# Out:
# UPFD(31, name=politifact, feature=profile)

# %%
class Net(torch.nn.Module):
    def __init__(self, in_channels, dim, out_channels):
        super(Net, self).__init__()

        self.conv1 = GINConv(
            Sequential(Linear(in_channels, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv2 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv3 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv4 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv5 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.lin1 = Linear(dim, dim)
        self.lin2 = Linear(dim, out_channels)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = self.conv2(x, edge_index)
        x = self.conv3(x, edge_index)
        x = self.conv4(x, edge_index)
        x = self.conv5(x, edge_index)
        x = global_add_pool(x, batch)
        x = self.lin1(x).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(train_dataset.num_features, 180, train_dataset.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.edge_index, data.batch)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()

    total_correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)
        total_correct += int((out.argmax(-1) == data.y).sum())
    return total_correct / len(loader.dataset)


for epoch in range(1, 101):
    loss = train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f} '
          f'Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 2.0201, Train Acc: 0.5806 Test Acc: 0.4887
# Epoch: 002, Loss: 0.7572, Train Acc: 0.5806 Test Acc: 0.4887
# Epoch: 003, Loss: 0.6795, Train Acc: 0.6129 Test Acc: 0.5068
# Epoch: 004, Loss: 1.5130, Train Acc: 0.6613 Test Acc: 0.5339
# Epoch: 005, Loss: 0.6816, Train Acc: 0.6290 Test Acc: 0.5158
# Epoch: 006, Loss: 0.5997, Train Acc: 0.6452 Test Acc: 0.5294
# Epoch: 007, Loss: 0.7183, Train Acc: 0.6613 Test Acc: 0.5837
# Epoch: 008, Loss: 0.5820, Train Acc: 0.7097 Test Acc: 0.6561
# Epoch: 009, Loss: 0.5705, Train Acc: 0.6935 Test Acc: 0.6742
# Epoch: 010, Loss: 0.6244, Train Acc: 0.6774 Test Acc: 0.6787
# Epoch: 011, Loss: 0.5114, Train Acc: 0.6774 Test Acc: 0.6833
# Epoch: 012, Loss: 0.3961, Train Acc: 0.6935 Test Acc: 0.7059
# Epoch: 013, Loss: 0.6316, Train Acc: 0.7097 Test Acc: 0.7195
# Epoch: 014, Loss: 0.4776, Train Acc: 0.7258 Test Acc: 0.7059
# Epoch: 015, Loss: 0.4590, Train Acc: 0.7258 Test Acc: 0.7014
# Epoch: 016, Loss: 0.5748, Train Acc: 0.7419 Test Acc: 0.7149
# Epoch: 017, Loss: 0.4250, Train Acc: 0.7419 Test Acc: 0.7240
# Epoch: 018, Loss: 0.4871, Train Acc: 0.7419 Test Acc: 0.7330
# Epoch: 019, Loss: 0.4534, Train Acc: 0.7419 Test Acc: 0.7104
# Epoch: 020, Loss: 0.4054, Train Acc: 0.7419 Test Acc: 0.7014
# Epoch: 021, Loss: 0.4242, Train Acc: 0.7581 Test Acc: 0.7059
# Epoch: 022, Loss: 0.3839, Train Acc: 0.7581 Test Acc: 0.6742
# Epoch: 023, Loss: 0.3855, Train Acc: 0.7742 Test Acc: 0.6471
# Epoch: 024, Loss: 0.4049, Train Acc: 0.7742 Test Acc: 0.6606
# Epoch: 025, Loss: 0.3385, Train Acc: 0.7581 Test Acc: 0.6833
# Epoch: 026, Loss: 0.3691, Train Acc: 0.7742 Test Acc: 0.6742
# Epoch: 027, Loss: 0.3338, Train Acc: 0.7742 Test Acc: 0.6561
# Epoch: 028, Loss: 0.3026, Train Acc: 0.7742 Test Acc: 0.6425
# Epoch: 029, Loss: 0.2887, Train Acc: 0.7742 Test Acc: 0.6561
# Epoch: 030, Loss: 0.2920, Train Acc: 0.7742 Test Acc: 0.6606
# Epoch: 031, Loss: 0.2725, Train Acc: 0.7742 Test Acc: 0.6561
# Epoch: 032, Loss: 0.2801, Train Acc: 0.7903 Test Acc: 0.6606
# Epoch: 033, Loss: 0.2879, Train Acc: 0.7903 Test Acc: 0.6516
# Epoch: 034, Loss: 0.2658, Train Acc: 0.8065 Test Acc: 0.6606
# Epoch: 035, Loss: 0.2526, Train Acc: 0.8065 Test Acc: 0.6652
# Epoch: 036, Loss: 0.2481, Train Acc: 0.8226 Test Acc: 0.6697
# Epoch: 037, Loss: 0.2463, Train Acc: 0.8226 Test Acc: 0.6742
# Epoch: 038, Loss: 0.2512, Train Acc: 0.8065 Test Acc: 0.6697
# Epoch: 039, Loss: 0.2285, Train Acc: 0.8065 Test Acc: 0.6652
# Epoch: 040, Loss: 0.2083, Train Acc: 0.8065 Test Acc: 0.6561
# Epoch: 041, Loss: 0.2153, Train Acc: 0.7903 Test Acc: 0.6652
# Epoch: 042, Loss: 0.2142, Train Acc: 0.8065 Test Acc: 0.6380
# Epoch: 043, Loss: 0.2039, Train Acc: 0.7903 Test Acc: 0.6606
# Epoch: 044, Loss: 0.2063, Train Acc: 0.8065 Test Acc: 0.6516
# Epoch: 045, Loss: 0.1867, Train Acc: 0.8065 Test Acc: 0.6606
# Epoch: 046, Loss: 0.1735, Train Acc: 0.8065 Test Acc: 0.6787
# Epoch: 047, Loss: 0.1574, Train Acc: 0.8387 Test Acc: 0.6878
# Epoch: 048, Loss: 0.1546, Train Acc: 0.8548 Test Acc: 0.6833
# Epoch: 049, Loss: 0.1874, Train Acc: 0.8548 Test Acc: 0.6833
# Epoch: 050, Loss: 0.1335, Train Acc: 0.8710 Test Acc: 0.6923
# Epoch: 051, Loss: 0.1588, Train Acc: 0.8226 Test Acc: 0.6787
# Epoch: 052, Loss: 0.1638, Train Acc: 0.8387 Test Acc: 0.6606
# Epoch: 053, Loss: 0.1511, Train Acc: 0.8710 Test Acc: 0.6923
# Epoch: 054, Loss: 0.1742, Train Acc: 0.9032 Test Acc: 0.7240
# Epoch: 055, Loss: 0.1407, Train Acc: 0.9194 Test Acc: 0.7195
# Epoch: 056, Loss: 0.1275, Train Acc: 0.9677 Test Acc: 0.7059
# Epoch: 057, Loss: 0.1426, Train Acc: 0.9194 Test Acc: 0.7104
# Epoch: 058, Loss: 0.1659, Train Acc: 0.8548 Test Acc: 0.6833
# Epoch: 059, Loss: 0.3462, Train Acc: 0.7742 Test Acc: 0.6652
# Epoch: 060, Loss: 0.4447, Train Acc: 0.9194 Test Acc: 0.7195
# Epoch: 061, Loss: 0.2332, Train Acc: 0.9355 Test Acc: 0.6878
# Epoch: 062, Loss: 0.2941, Train Acc: 0.8871 Test Acc: 0.6606
# Epoch: 063, Loss: 0.2617, Train Acc: 0.8871 Test Acc: 0.6471
# Epoch: 064, Loss: 0.2700, Train Acc: 0.8710 Test Acc: 0.6923
# Epoch: 065, Loss: 0.2187, Train Acc: 0.9355 Test Acc: 0.7059
# Epoch: 066, Loss: 0.2076, Train Acc: 0.9355 Test Acc: 0.7059
# Epoch: 067, Loss: 0.2258, Train Acc: 0.9032 Test Acc: 0.7014
# Epoch: 068, Loss: 0.2330, Train Acc: 0.9032 Test Acc: 0.7104
# Epoch: 069, Loss: 0.2278, Train Acc: 0.9032 Test Acc: 0.7195
# Epoch: 070, Loss: 0.2170, Train Acc: 0.9194 Test Acc: 0.7195
# Epoch: 071, Loss: 0.2249, Train Acc: 0.9194 Test Acc: 0.7285
# Epoch: 072, Loss: 0.2155, Train Acc: 0.9194 Test Acc: 0.7376
# Epoch: 073, Loss: 0.1972, Train Acc: 0.9032 Test Acc: 0.7421
# Epoch: 074, Loss: 0.2051, Train Acc: 0.9032 Test Acc: 0.7421
# Epoch: 075, Loss: 0.1932, Train Acc: 0.9032 Test Acc: 0.7421
# Epoch: 076, Loss: 0.1689, Train Acc: 0.9032 Test Acc: 0.7376
# Epoch: 077, Loss: 0.1787, Train Acc: 0.9032 Test Acc: 0.7602
# Epoch: 078, Loss: 0.1787, Train Acc: 0.9032 Test Acc: 0.7511
# Epoch: 079, Loss: 0.1458, Train Acc: 0.9194 Test Acc: 0.7466
# Epoch: 080, Loss: 0.1354, Train Acc: 0.9194 Test Acc: 0.7511
# Epoch: 081, Loss: 0.1203, Train Acc: 0.9194 Test Acc: 0.7647
# Epoch: 082, Loss: 0.1186, Train Acc: 0.9355 Test Acc: 0.7738
# Epoch: 083, Loss: 0.1096, Train Acc: 0.9355 Test Acc: 0.7692
# Epoch: 084, Loss: 0.0934, Train Acc: 0.9677 Test Acc: 0.7738
# Epoch: 085, Loss: 0.0818, Train Acc: 0.9839 Test Acc: 0.7828
# Epoch: 086, Loss: 0.0803, Train Acc: 0.9839 Test Acc: 0.7828
# Epoch: 087, Loss: 0.0630, Train Acc: 0.9839 Test Acc: 0.7828
# Epoch: 088, Loss: 0.0591, Train Acc: 0.9839 Test Acc: 0.7738
# Epoch: 089, Loss: 0.0503, Train Acc: 0.9677 Test Acc: 0.7692
# Epoch: 090, Loss: 0.0423, Train Acc: 0.9677 Test Acc: 0.7647
# Epoch: 091, Loss: 0.0473, Train Acc: 0.9677 Test Acc: 0.7692
# Epoch: 092, Loss: 0.0332, Train Acc: 0.9839 Test Acc: 0.7783
# Epoch: 093, Loss: 0.0319, Train Acc: 0.9839 Test Acc: 0.7828
# Epoch: 094, Loss: 0.0295, Train Acc: 1.0000 Test Acc: 0.7783
# Epoch: 095, Loss: 0.0277, Train Acc: 1.0000 Test Acc: 0.7783
# Epoch: 096, Loss: 0.0232, Train Acc: 1.0000 Test Acc: 0.7783
# Epoch: 097, Loss: 0.0272, Train Acc: 0.9194 Test Acc: 0.7602
# Epoch: 098, Loss: 0.1944, Train Acc: 0.8065 Test Acc: 0.7240
# Epoch: 099, Loss: 2.0370, Train Acc: 0.9032 Test Acc: 0.7647
# Epoch: 100, Loss: 0.2866, Train Acc: 0.9194 Test Acc: 0.7602
